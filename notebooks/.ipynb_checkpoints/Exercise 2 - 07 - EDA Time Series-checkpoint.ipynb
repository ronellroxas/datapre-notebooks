# %% [markdown]
# # Exercise: EDA of Time Series
#
# Let's practice our EDA skills with another type of data! In this exercise, we will prepare and analyze a MRT3 passenger dataset.
#
# Using this dataset, you need to wrangle the data to come up with visualizations to know more about the passenger trends and patterns across the whole MRT3 system.
#
# What questions would you like to answer with the available dataset?
#
# **IMPORTANT:** Copy this notebook and make changes in that copy. Do not push changes to this notebook.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import datetime

from pathlib import Path

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
DSDATA = Path(os.getenv('DSDATA'))

# %%
df = pd.read_csv(DSDATA / '2013_mrt_hourly_daily_ridership_tidy.csv')
df.head(5)
# Out:
#      month  day           time north_avenue_entry north_avenue_exit  \
# 0  January    1  03:00 - 03:59                  -                 -
# 1  January    1  04:00 - 04:59                  -                 -
# 2  January    1  05:00 - 05:59                367                94
# 3  January    1  06:00 - 06:59                533               610
# 4  January    1  07:00 - 07:59                678               800
#
#   quezon_avenue_entry quezon_avenue_exit gma_kamuning_entry gma_kamuning_exit  \
# 0                   -                  -                  -                 -
# 1                   -                  -                  -                 -
# 2                 127                 57                113                21
# 3                 327                247                210               113
# 4                 373                426                209               209
#
#   cubao_entry  ... guadalupe_entry guadalupe_exit buendia_entry buendia_exit  \
# 0           -  ...               -              -             -            -
# 1           -  ...               -              -             -            -
# 2         316  ...             124             56            40           38
# 3         597  ...             352            278           181          191
# 4         724  ...             462            364           256          143
#
#   ayala_avenue_entry ayala_avenue_exit magallanes_entry magallanes_exit  \
# 0                  -                 -                -               -
# 1                  -                 -                -               -
# 2                100               123               70              84
# 3                379               404              307             256
# 4                458               366              378             290
#
#   taft_entry taft_exit
# 0          -         -
# 1          -         -
# 2        359       192
# 3        762       820
# 4       1079      1174
#
# [5 rows x 29 columns]

# %%
def getFirstHour(time):
    return time[0:2]

# %%
df["time"] = df["time"].map(getFirstHour)

# %%
df.head()
# Out:
#      month  day time north_avenue_entry north_avenue_exit quezon_avenue_entry  \
# 0  January    1   03                  -                 -                   -
# 1  January    1   04                  -                 -                   -
# 2  January    1   05                367                94                 127
# 3  January    1   06                533               610                 327
# 4  January    1   07                678               800                 373
#
#   quezon_avenue_exit gma_kamuning_entry gma_kamuning_exit cubao_entry  ...  \
# 0                  -                  -                 -           -  ...
# 1                  -                  -                 -           -  ...
# 2                 57                113                21         316  ...
# 3                247                210               113         597  ...
# 4                426                209               209         724  ...
#
#   guadalupe_entry guadalupe_exit buendia_entry buendia_exit  \
# 0               -              -             -            -
# 1               -              -             -            -
# 2             124             56            40           38
# 3             352            278           181          191
# 4             462            364           256          143
#
#   ayala_avenue_entry ayala_avenue_exit magallanes_entry magallanes_exit  \
# 0                  -                 -                -               -
# 1                  -                 -                -               -
# 2                100               123               70              84
# 3                379               404              307             256
# 4                458               366              378             290
#
#   taft_entry taft_exit
# 0          -         -
# 1          -         -
# 2        359       192
# 3        762       820
# 4       1079      1174
#
# [5 rows x 29 columns]

# %%
def removeDashes(value):
    result = re.sub(r"-", "0", value)
    result = result.strip()
    return result

# %%
df[["time", "north_avenue_entry", "north_avenue_exit", 
    "quezon_avenue_entry", "quezon_avenue_exit", 
    "gma_kamuning_entry", "gma_kamuning_exit", 
    "cubao_entry", "cubao_exit", 
    "santolan_entry", "santolan_exit", 
    "ortigas_entry", "ortigas_exit", 
    "shaw_blvd_entry", "shaw_blvd_exit", 
    "boni_avenue_entry", "boni_avenue_exit", 
    "guadalupe_entry", "guadalupe_exit", 
    "buendia_entry", "buendia_exit", 
    "ayala_avenue_entry", "ayala_avenue_exit", 
    "magallanes_entry", "magallanes_exit", 
    "taft_entry", "taft_exit"]] = df[["time", "north_avenue_entry", "north_avenue_exit", 
    "quezon_avenue_entry", "quezon_avenue_exit", 
    "gma_kamuning_entry", "gma_kamuning_exit", 
    "cubao_entry", "cubao_exit", 
    "santolan_entry", "santolan_exit", 
    "ortigas_entry", "ortigas_exit", 
    "shaw_blvd_entry", "shaw_blvd_exit", 
    "boni_avenue_entry", "boni_avenue_exit", 
    "guadalupe_entry", "guadalupe_exit", 
    "buendia_entry", "buendia_exit", 
    "ayala_avenue_entry", "ayala_avenue_exit", 
    "magallanes_entry", "magallanes_exit", 
    "taft_entry", "taft_exit"]].applymap(removeDashes)

# %%
df[["time", "north_avenue_entry", "north_avenue_exit", 
    "quezon_avenue_entry", "quezon_avenue_exit", 
    "gma_kamuning_entry", "gma_kamuning_exit", 
    "cubao_entry", "cubao_exit", 
    "santolan_entry", "santolan_exit", 
    "ortigas_entry", "ortigas_exit", 
    "shaw_blvd_entry", "shaw_blvd_exit", 
    "boni_avenue_entry", "boni_avenue_exit", 
    "guadalupe_entry", "guadalupe_exit", 
    "buendia_entry", "buendia_exit", 
    "ayala_avenue_entry", "ayala_avenue_exit", 
    "magallanes_entry", "magallanes_exit", 
    "taft_entry", "taft_exit"]] = df[["time", "north_avenue_entry", "north_avenue_exit", 
    "quezon_avenue_entry", "quezon_avenue_exit", 
    "gma_kamuning_entry", "gma_kamuning_exit", 
    "cubao_entry", "cubao_exit", 
    "santolan_entry", "santolan_exit", 
    "ortigas_entry", "ortigas_exit", 
    "shaw_blvd_entry", "shaw_blvd_exit", 
    "boni_avenue_entry", "boni_avenue_exit", 
    "guadalupe_entry", "guadalupe_exit", 
    "buendia_entry", "buendia_exit", 
    "ayala_avenue_entry", "ayala_avenue_exit", 
    "magallanes_entry", "magallanes_exit", 
    "taft_entry", "taft_exit"]].applymap(pd.to_numeric)

# %%
def convertMonthToNum(month):
    dt = datetime.datetime.strptime(month, "%B")
    return dt.month

# %%
df["month"] = df["month"].map(convertMonthToNum)

# %%
df.describe()
# Out:
#              month          day         time  north_avenue_entry  \
# count  8760.000000  8760.000000  8760.000000         8760.000000
# mean      6.526027    15.720548    11.500000         3251.288584
# std       3.448048     8.796749     6.922582         2940.477189
# min       1.000000     1.000000     0.000000            0.000000
# 25%       4.000000     8.000000     5.750000           49.000000
# 50%       7.000000    16.000000    11.500000         3246.000000
# 75%      10.000000    23.000000    17.250000         4290.000000
# max      12.000000    31.000000    23.000000        13731.000000
#
#        north_avenue_exit  quezon_avenue_entry  quezon_avenue_exit  \
# count        8760.000000          8760.000000         8760.000000
# mean         2191.639954          1447.869406         1525.584018
# std          2005.089049          1222.810864         1320.966882
# min             0.000000             0.000000            0.000000
# 25%           117.000000            62.000000           26.000000
# 50%          2102.000000          1520.000000         1490.000000
# 75%          2946.500000          2173.250000         2271.250000
# max         10265.000000          5865.000000         6110.000000
#
#        gma_kamuning_entry  gma_kamuning_exit  cubao_entry  ...  \
# count         8760.000000        8760.000000  8760.000000  ...
# mean           831.943950         625.038128  2003.393836  ...
# std            664.295373         514.185880  1425.458898  ...
# min              0.000000           0.000000     0.000000  ...
# 25%             47.000000           5.000000   148.000000  ...
# 50%            871.000000         617.000000  2411.000000  ...
# 75%           1357.000000         984.000000  3159.000000  ...
# max           3102.000000        2035.000000  5514.000000  ...
#
#        guadalupe_entry  guadalupe_exit  buendia_entry  buendia_exit  \
# count      8760.000000     8760.000000    8760.000000   8760.000000
# mean       1440.768493     1391.035274     674.520776    790.007306
# std        1082.055418     1050.328269     761.761083    928.635335
# min           0.000000        0.000000       0.000000      0.000000
# 25%           0.000000        0.000000       0.000000      0.000000
# 50%        1681.000000     1631.000000     478.500000    566.000000
# 75%        2231.250000     2102.000000     872.250000   1093.000000
# max        5150.000000     6095.000000    5104.000000   8630.000000
#
#        ayala_avenue_entry  ayala_avenue_exit  magallanes_entry  \
# count         8760.000000        8760.000000       8760.000000
# mean          1648.371575        1971.575342       1408.229680
# std           1653.283126        1790.117664       1293.345218
# min              0.000000           0.000000          0.000000
# 25%              0.000000           0.000000          0.000000
# 50%           1332.500000        1846.500000       1396.000000
# 75%           2260.250000        2992.250000       2018.250000
# max           9264.000000       10955.000000       6142.000000
#
#        magallanes_exit   taft_entry    taft_exit
# count      8760.000000  8760.000000  8760.000000
# mean       1030.165639  3321.425913  3027.424087
# std        1051.286395  2550.732800  2257.189573
# min           0.000000     0.000000     0.000000
# 25%           0.000000     0.000000     0.000000
# 50%         886.000000  3718.000000  3576.000000
# 75%        1382.000000  5057.000000  4662.250000
# max        6065.000000  9500.000000  9182.000000
#
# [8 rows x 29 columns]

# %%
df_tidy = df.melt(id_vars=["month", "day", "time"], value_vars=["north_avenue_entry", "north_avenue_exit", 
    "quezon_avenue_entry", "quezon_avenue_exit", 
    "gma_kamuning_entry", "gma_kamuning_exit", 
    "cubao_entry", "cubao_exit", 
    "santolan_entry", "santolan_exit", 
    "ortigas_entry", "ortigas_exit", 
    "shaw_blvd_entry", "shaw_blvd_exit", 
    "boni_avenue_entry", "boni_avenue_exit", 
    "guadalupe_entry", "guadalupe_exit", 
    "buendia_entry", "buendia_exit", 
    "ayala_avenue_entry", "ayala_avenue_exit", 
    "magallanes_entry", "magallanes_exit", 
    "taft_entry", "taft_exit"], var_name="station", value_name="count")

df_tidy.head(30)
# Out:
#     month  day  time             station  count
# 0       1    1     3  north_avenue_entry      0
# 1       1    1     4  north_avenue_entry      0
# 2       1    1     5  north_avenue_entry    367
# 3       1    1     6  north_avenue_entry    533
# 4       1    1     7  north_avenue_entry    678
# 5       1    1     8  north_avenue_entry    759
# 6       1    1     9  north_avenue_entry   1089
# 7       1    1    10  north_avenue_entry   1972
# 8       1    1    11  north_avenue_entry   2513
# 9       1    1    12  north_avenue_entry   2064
# 10      1    1    13  north_avenue_entry   1607
# 11      1    1    14  north_avenue_entry   1586
# 12      1    1    15  north_avenue_entry   2237
# 13      1    1    16  north_avenue_entry   2535
# 14      1    1    17  north_avenue_entry   2683
# 15      1    1    18  north_avenue_entry   2567
# 16      1    1    19  north_avenue_entry   2559
# 17      1    1    20  north_avenue_entry   2384
# 18      1    1    21  north_avenue_entry   1691
# 19      1    1    22  north_avenue_entry      1
# 20      1    1    23  north_avenue_entry      0
# 21      1    1     0  north_avenue_entry      0
# 22      1    1     1  north_avenue_entry      0
# 23      1    1     2  north_avenue_entry      0
# 24      1    2     3  north_avenue_entry      0
# 25      1    2     4  north_avenue_entry     75
# 26      1    2     5  north_avenue_entry   4034
# 27      1    2     6  north_avenue_entry   7877
# 28      1    2     7  north_avenue_entry  10200
# 29      1    2     8  north_avenue_entry   7694

# %%
def cleanStationNames(station_name):
    if re.search(r"_entry", station_name):
        pos = re.search(r"_entry", station_name).start()
        return station_name[pos+1:], station_name[:pos]
    elif re.search(r"_exit", station_name):
        pos = re.search(r"_exit", station_name).start()
        return station_name[pos+1:], station_name[:pos]
    else:
        return station_name, station_name

# %%
df_tidy["gate"], df_tidy["station"] = zip(*df_tidy["station"].apply(cleanStationNames))

# %% [markdown]
#    ### EDA

# %%
monthly = df_tidy.groupby(["station", "month", "gate"], as_index=False)["count"].sum()
monthly["count"] = monthly["count"]/1000000
monthly.head()
# Out:
#         station  month   gate     count
# 0  ayala_avenue      1  entry  1.233429
# 1  ayala_avenue      1   exit  1.481022
# 2  ayala_avenue      2  entry  1.153228
# 3  ayala_avenue      2   exit  1.292383
# 4  ayala_avenue      3  entry  1.076803

# %%
northave_plot = sns.lineplot(data=df_tidy[df_tidy["station"] == "north_avenue"], x="time", y="count", hue="gate")

# %%
annual_plot = sns.lineplot(data=monthly, x="month", y="count", hue="station")

# %%
annual_plot = sns.FacetGrid(monthly, col="station", col_wrap=3, height=4)
annual_plot.map(sns.lineplot, "month", "count")
annual_plot.set(xticks=range(1, 13, 1))
annual_plot.set_axis_labels("", "Total passengers (in millions)")

# %%
plot = sns.barplot(data=monthly, x="count", y="station", hue="gate")
plot.set(xlabel="Total passengers (in millions)", ylabel="")
# Out:
# [Text(0, 0.5, ''), Text(0.5, 0, 'Total passengers (in millions)')]
